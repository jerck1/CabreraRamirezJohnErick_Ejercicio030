# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import sklearn.preprocessing
import torch
import torchvision
import torchvision.datasets
import torchvision.models
import torchvision.transforms

# %%
numeros = sklearn.datasets.load_digits()
imagenes = numeros['images']  # Hay 1797 digitos representados en imagenes 8x8
n_imagenes = len(imagenes)
X = imagenes.copy()
Y = numeros['target']
print(np.shape(X))
# Out:
# (1797, 8, 8)

# %%
inputs = torch.autograd.Variable(torch.Tensor(X).float()).unsqueeze(1)
print(inputs.size())
# Out:
# torch.Size([1797, 1, 8, 8])

# %%
# muestra algunos ejemplos

n_items = inputs.data.size()[0]
random_items = np.random.choice(np.arange(n_items), 5)

plt.figure(figsize=(14,5))
for i in range(5):
    plt.subplot(1,5,i+1)
    item  = random_items[i]
    plt.imshow(inputs[item][0].detach().numpy())
    plt.title(Y[item])

# %%
# normaliza
mean = inputs.mean(dim=0)
std = inputs.std(dim=0)
std[std==0]=1.0

for i in range(len(inputs)):
    inputs[i] = (inputs[i])/std
np.shape(inputs)
# Out:
# torch.Size([1797, 1, 8, 8])

# %%
# define el autoencoder
class Autoencoder(torch.nn.Module):
    def __init__(self):
        super(Autoencoder,self).__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 16, kernel_size=3),
            torch.nn.Conv2d(16,8,kernel_size=3),
            torch.nn.Conv2d(8,4,kernel_size=3))
        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(4,8,kernel_size=3),
            torch.nn.ConvTranspose2d(8,16,kernel_size=3),
            torch.nn.ConvTranspose2d(16,1,kernel_size=3))
    def forward(self,x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# define el autoencoder
class Autoencoder(torch.nn.Module):
    def __init__(self,k1, k2, k3):
        super(Autoencoder,self).__init__()
        #k1=16; k2=8; k3=4
        self.k1=k1
        self.k2=k2
        self.k3=k3
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, k1, kernel_size=3),
            torch.nn.Conv2d(k1,k2,kernel_size=3),
            torch.nn.Conv2d(k2,k3,kernel_size=3))
        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(k3,k2,kernel_size=3),
            torch.nn.ConvTranspose2d(k2,k1,kernel_size=3),
            torch.nn.ConvTranspose2d(k1,1,kernel_size=3))
    def forward(self,x,k1, k2, k3):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-403d29e2fe28> in <module>
#       1 # inicializa modelo, loss y optimizador
#       2 num_epochs = 100
# ----> 3 model = Autoencoder(k1,k2,k3)
#       4 print(model)
#       5 distance = torch.nn.MSELoss()
#
# NameError: name 'k2' is not defined

# %%
# entrenamiento
# inicializa modelo, loss y optimizador
k1=16
k2=8
#k3=4
latent_space=[2,4,6,8]
n_c_tot=[]
loss_tot=[]
for k3 in latent_space:
    num_epochs = 100
    model = Autoencoder(k1,k2,k3)
    print(model)
    distance = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1E-4)
    loss_list = [] 
    for epoch in range(num_epochs):
        output = model(inputs,k1,8,4)
        loss = distance(output, inputs)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        loss_list.append(loss.item())
        print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
    loss_tot.append(loss_list[-1])
    #type(loss.item())
    n_c=0
    for m in model.parameters():
        n_c+=m.flatten().size()[0]
    n_c_tot.append(n_c)
    print(np)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 2, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(2, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.6391
# epoch [2/100], loss:2.4814
# epoch [3/100], loss:2.3064
# epoch [4/100], loss:2.1385
# epoch [5/100], loss:1.9359
# epoch [6/100], loss:1.6737
# epoch [7/100], loss:1.5745
# epoch [8/100], loss:1.5151
# epoch [9/100], loss:1.3232
# epoch [10/100], loss:1.2843
# epoch [11/100], loss:1.2739
# epoch [12/100], loss:1.1828
# epoch [13/100], loss:1.0974
# epoch [14/100], loss:1.0893
# epoch [15/100], loss:1.0839
# epoch [16/100], loss:1.0403
# epoch [17/100], loss:1.0095
# epoch [18/100], loss:0.9928
# epoch [19/100], loss:0.9757
# epoch [20/100], loss:0.9586
# epoch [21/100], loss:0.9398
# epoch [22/100], loss:0.9121
# epoch [23/100], loss:0.8862
# epoch [24/100], loss:0.8775
# epoch [25/100], loss:0.8759
# epoch [26/100], loss:0.8650
# epoch [27/100], loss:0.8523
# epoch [28/100], loss:0.8490
# epoch [29/100], loss:0.8476
# epoch [30/100], loss:0.8395
# epoch [31/100], loss:0.8294
# epoch [32/100], loss:0.8207
# epoch [33/100], loss:0.8132
# epoch [34/100], loss:0.8084
# epoch [35/100], loss:0.8069
# epoch [36/100], loss:0.8047
# epoch [37/100], loss:0.8001
# epoch [38/100], loss:0.7970
# epoch [39/100], loss:0.7972
# epoch [40/100], loss:0.7971
# epoch [41/100], loss:0.7938
# epoch [42/100], loss:0.7886
# epoch [43/100], loss:0.7845
# epoch [44/100], loss:0.7820
# epoch [45/100], loss:0.7794
# epoch [46/100], loss:0.7768
# epoch [47/100], loss:0.7747
# epoch [48/100], loss:0.7728
# epoch [49/100], loss:0.7709
# epoch [50/100], loss:0.7694
# epoch [51/100], loss:0.7679
# epoch [52/100], loss:0.7657
# epoch [53/100], loss:0.7633
# epoch [54/100], loss:0.7620
# epoch [55/100], loss:0.7612
# epoch [56/100], loss:0.7600
# epoch [57/100], loss:0.7586
# epoch [58/100], loss:0.7575
# epoch [59/100], loss:0.7565
# epoch [60/100], loss:0.7551
# epoch [61/100], loss:0.7538
# epoch [62/100], loss:0.7525
# epoch [63/100], loss:0.7514
# epoch [64/100], loss:0.7504
# epoch [65/100], loss:0.7497
# epoch [66/100], loss:0.7488
# epoch [67/100], loss:0.7477
# epoch [68/100], loss:0.7469
# epoch [69/100], loss:0.7461
# epoch [70/100], loss:0.7451
# epoch [71/100], loss:0.7443
# epoch [72/100], loss:0.7436
# epoch [73/100], loss:0.7429
# epoch [74/100], loss:0.7422
# epoch [75/100], loss:0.7416
# epoch [76/100], loss:0.7409
# epoch [77/100], loss:0.7403
# epoch [78/100], loss:0.7397
# epoch [79/100], loss:0.7392
# epoch [80/100], loss:0.7386
# epoch [81/100], loss:0.7381
# epoch [82/100], loss:0.7375
# epoch [83/100], loss:0.7370
# epoch [84/100], loss:0.7365
# epoch [85/100], loss:0.7360
# epoch [86/100], loss:0.7355
# epoch [87/100], loss:0.7351
# epoch [88/100], loss:0.7346
# epoch [89/100], loss:0.7341
# epoch [90/100], loss:0.7337
# epoch [91/100], loss:0.7332
# epoch [92/100], loss:0.7328
# epoch [93/100], loss:0.7324
# epoch [94/100], loss:0.7320
# epoch [95/100], loss:0.7316
# epoch [96/100], loss:0.7311
# epoch [97/100], loss:0.7307
# epoch [98/100], loss:0.7303
# epoch [99/100], loss:0.7300
# epoch [100/100], loss:0.7296
# 2931
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:1.9722
# epoch [2/100], loss:1.8141
# epoch [3/100], loss:1.6330
# epoch [4/100], loss:1.4367
# epoch [5/100], loss:1.4218
# epoch [6/100], loss:1.2859
# epoch [7/100], loss:1.2051
# epoch [8/100], loss:1.1960
# epoch [9/100], loss:1.1355
# epoch [10/100], loss:1.0677
# epoch [11/100], loss:1.0321
# epoch [12/100], loss:0.9781
# epoch [13/100], loss:0.9553
# epoch [14/100], loss:0.9299
# epoch [15/100], loss:0.9134
# epoch [16/100], loss:0.9190
# epoch [17/100], loss:0.8955
# epoch [18/100], loss:0.8747
# epoch [19/100], loss:0.8663
# epoch [20/100], loss:0.8405
# epoch [21/100], loss:0.8207
# epoch [22/100], loss:0.8160
# epoch [23/100], loss:0.8117
# epoch [24/100], loss:0.8019
# epoch [25/100], loss:0.7910
# epoch [26/100], loss:0.7827
# epoch [27/100], loss:0.7742
# epoch [28/100], loss:0.7624
# epoch [29/100], loss:0.7511
# epoch [30/100], loss:0.7451
# epoch [31/100], loss:0.7417
# epoch [32/100], loss:0.7362
# epoch [33/100], loss:0.7296
# epoch [34/100], loss:0.7239
# epoch [35/100], loss:0.7177
# epoch [36/100], loss:0.7112
# epoch [37/100], loss:0.7059
# epoch [38/100], loss:0.7012
# epoch [39/100], loss:0.6959
# epoch [40/100], loss:0.6901
# epoch [41/100], loss:0.6849
# epoch [42/100], loss:0.6803
# epoch [43/100], loss:0.6756
# epoch [44/100], loss:0.6711
# epoch [45/100], loss:0.6670
# epoch [46/100], loss:0.6625
# epoch [47/100], loss:0.6573
# epoch [48/100], loss:0.6523
# epoch [49/100], loss:0.6476
# epoch [50/100], loss:0.6433
# epoch [51/100], loss:0.6392
# epoch [52/100], loss:0.6351
# epoch [53/100], loss:0.6306
# epoch [54/100], loss:0.6259
# epoch [55/100], loss:0.6217
# epoch [56/100], loss:0.6179
# epoch [57/100], loss:0.6141
# epoch [58/100], loss:0.6103
# epoch [59/100], loss:0.6068
# epoch [60/100], loss:0.6032
# epoch [61/100], loss:0.5996
# epoch [62/100], loss:0.5962
# epoch [63/100], loss:0.5928
# epoch [64/100], loss:0.5895
# epoch [65/100], loss:0.5864
# epoch [66/100], loss:0.5835
# epoch [67/100], loss:0.5806
# epoch [68/100], loss:0.5778
# epoch [69/100], loss:0.5753
# epoch [70/100], loss:0.5728
# epoch [71/100], loss:0.5704
# epoch [72/100], loss:0.5681
# epoch [73/100], loss:0.5659
# epoch [74/100], loss:0.5639
# epoch [75/100], loss:0.5619
# epoch [76/100], loss:0.5601
# epoch [77/100], loss:0.5584
# epoch [78/100], loss:0.5568
# epoch [79/100], loss:0.5554
# epoch [80/100], loss:0.5540
# epoch [81/100], loss:0.5529
# epoch [82/100], loss:0.5517
# epoch [83/100], loss:0.5506
# epoch [84/100], loss:0.5496
# epoch [85/100], loss:0.5485
# epoch [86/100], loss:0.5475
# epoch [87/100], loss:0.5466
# epoch [88/100], loss:0.5456
# epoch [89/100], loss:0.5447
# epoch [90/100], loss:0.5437
# epoch [91/100], loss:0.5429
# epoch [92/100], loss:0.5420
# epoch [93/100], loss:0.5411
# epoch [94/100], loss:0.5403
# epoch [95/100], loss:0.5395
# epoch [96/100], loss:0.5387
# epoch [97/100], loss:0.5380
# epoch [98/100], loss:0.5372
# epoch [99/100], loss:0.5365
# epoch [100/100], loss:0.5358
# 2931
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 6, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(6, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.0359
# epoch [2/100], loss:1.8725
# epoch [3/100], loss:1.6345
# epoch [4/100], loss:1.4140
# epoch [5/100], loss:1.5317
# epoch [6/100], loss:1.2360
# epoch [7/100], loss:1.2441
# epoch [8/100], loss:1.2707
# epoch [9/100], loss:1.2423
# epoch [10/100], loss:1.1659
# epoch [11/100], loss:1.0731
# epoch [12/100], loss:1.0217
# epoch [13/100], loss:1.0394
# epoch [14/100], loss:1.0266
# epoch [15/100], loss:0.9819
# epoch [16/100], loss:0.9675
# epoch [17/100], loss:0.9626
# epoch [18/100], loss:0.9408
# epoch [19/100], loss:0.9066
# epoch [20/100], loss:0.8838
# epoch [21/100], loss:0.8821
# epoch [22/100], loss:0.8740
# epoch [23/100], loss:0.8546
# epoch [24/100], loss:0.8403
# epoch [25/100], loss:0.8278
# epoch [26/100], loss:0.8138
# epoch [27/100], loss:0.8019
# epoch [28/100], loss:0.7942
# epoch [29/100], loss:0.7872
# epoch [30/100], loss:0.7759
# epoch [31/100], loss:0.7618
# epoch [32/100], loss:0.7505
# epoch [33/100], loss:0.7412
# epoch [34/100], loss:0.7291
# epoch [35/100], loss:0.7152
# epoch [36/100], loss:0.7046
# epoch [37/100], loss:0.6975
# epoch [38/100], loss:0.6890
# epoch [39/100], loss:0.6795
# epoch [40/100], loss:0.6731
# epoch [41/100], loss:0.6667
# epoch [42/100], loss:0.6567
# epoch [43/100], loss:0.6478
# epoch [44/100], loss:0.6425
# epoch [45/100], loss:0.6372
# epoch [46/100], loss:0.6299
# epoch [47/100], loss:0.6234
# epoch [48/100], loss:0.6187
# epoch [49/100], loss:0.6136
# epoch [50/100], loss:0.6083
# epoch [51/100], loss:0.6041
# epoch [52/100], loss:0.5999
# epoch [53/100], loss:0.5954
# epoch [54/100], loss:0.5920
# epoch [55/100], loss:0.5891
# epoch [56/100], loss:0.5853
# epoch [57/100], loss:0.5817
# epoch [58/100], loss:0.5791
# epoch [59/100], loss:0.5758
# epoch [60/100], loss:0.5721
# epoch [61/100], loss:0.5692
# epoch [62/100], loss:0.5662
# epoch [63/100], loss:0.5627
# epoch [64/100], loss:0.5597
# epoch [65/100], loss:0.5571
# epoch [66/100], loss:0.5541
# epoch [67/100], loss:0.5511
# epoch [68/100], loss:0.5487
# epoch [69/100], loss:0.5461
# epoch [70/100], loss:0.5433
# epoch [71/100], loss:0.5407
# epoch [72/100], loss:0.5380
# epoch [73/100], loss:0.5353
# epoch [74/100], loss:0.5327
# epoch [75/100], loss:0.5300
# epoch [76/100], loss:0.5272
# epoch [77/100], loss:0.5246
# epoch [78/100], loss:0.5219
# epoch [79/100], loss:0.5192
# epoch [80/100], loss:0.5166
# epoch [81/100], loss:0.5140
# epoch [82/100], loss:0.5114
# epoch [83/100], loss:0.5089
# epoch [84/100], loss:0.5065
# epoch [85/100], loss:0.5040
# epoch [86/100], loss:0.5017
# epoch [87/100], loss:0.4994
# epoch [88/100], loss:0.4972
# epoch [89/100], loss:0.4950
# epoch [90/100], loss:0.4929
# epoch [91/100], loss:0.4909
# epoch [92/100], loss:0.4890
# epoch [93/100], loss:0.4871
# epoch [94/100], loss:0.4853
# epoch [95/100], loss:0.4836
# epoch [96/100], loss:0.4819
# epoch [97/100], loss:0.4802
# epoch [98/100], loss:0.4786
# epoch [99/100], loss:0.4771
# epoch [100/100], loss:0.4756
# 2931
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.0698
# epoch [2/100], loss:1.7172
# epoch [3/100], loss:1.4212
# epoch [4/100], loss:1.3385
# epoch [5/100], loss:1.2013
# epoch [6/100], loss:1.1749
# epoch [7/100], loss:1.1023
# epoch [8/100], loss:1.0948
# epoch [9/100], loss:1.0722
# epoch [10/100], loss:1.0029
# epoch [11/100], loss:0.9990
# epoch [12/100], loss:0.9849
# epoch [13/100], loss:0.9514
# epoch [14/100], loss:0.9304
# epoch [15/100], loss:0.9154
# epoch [16/100], loss:0.8777
# epoch [17/100], loss:0.8523
# epoch [18/100], loss:0.8579
# epoch [19/100], loss:0.8561
# epoch [20/100], loss:0.8383
# epoch [21/100], loss:0.8192
# epoch [22/100], loss:0.7997
# epoch [23/100], loss:0.7860
# epoch [24/100], loss:0.7788
# epoch [25/100], loss:0.7686
# epoch [26/100], loss:0.7549
# epoch [27/100], loss:0.7447
# epoch [28/100], loss:0.7366
# epoch [29/100], loss:0.7241
# epoch [30/100], loss:0.7101
# epoch [31/100], loss:0.6991
# epoch [32/100], loss:0.6889
# epoch [33/100], loss:0.6803
# epoch [34/100], loss:0.6766
# epoch [35/100], loss:0.6720
# epoch [36/100], loss:0.6645
# epoch [37/100], loss:0.6589
# epoch [38/100], loss:0.6520
# epoch [39/100], loss:0.6425
# epoch [40/100], loss:0.6347
# epoch [41/100], loss:0.6284
# epoch [42/100], loss:0.6216
# epoch [43/100], loss:0.6152
# epoch [44/100], loss:0.6087
# epoch [45/100], loss:0.6013
# epoch [46/100], loss:0.5939
# epoch [47/100], loss:0.5864
# epoch [48/100], loss:0.5793
# epoch [49/100], loss:0.5733
# epoch [50/100], loss:0.5671
# epoch [51/100], loss:0.5611
# epoch [52/100], loss:0.5557
# epoch [53/100], loss:0.5500
# epoch [54/100], loss:0.5448
# epoch [55/100], loss:0.5395
# epoch [56/100], loss:0.5345
# epoch [57/100], loss:0.5293
# epoch [58/100], loss:0.5236
# epoch [59/100], loss:0.5184
# epoch [60/100], loss:0.5137
# epoch [61/100], loss:0.5094
# epoch [62/100], loss:0.5056
# epoch [63/100], loss:0.5017
# epoch [64/100], loss:0.4981
# epoch [65/100], loss:0.4944
# epoch [66/100], loss:0.4909
# epoch [67/100], loss:0.4873
# epoch [68/100], loss:0.4837
# epoch [69/100], loss:0.4804
# epoch [70/100], loss:0.4771
# epoch [71/100], loss:0.4741
# epoch [72/100], loss:0.4712
# epoch [73/100], loss:0.4684
# epoch [74/100], loss:0.4657
# epoch [75/100], loss:0.4631
# epoch [76/100], loss:0.4605
# epoch [77/100], loss:0.4580
# epoch [78/100], loss:0.4555
# epoch [79/100], loss:0.4530
# epoch [80/100], loss:0.4506
# epoch [81/100], loss:0.4483
# epoch [82/100], loss:0.4460
# epoch [83/100], loss:0.4437
# epoch [84/100], loss:0.4415
# epoch [85/100], loss:0.4393
# epoch [86/100], loss:0.4372
# epoch [87/100], loss:0.4352
# epoch [88/100], loss:0.4331
# epoch [89/100], loss:0.4311
# epoch [90/100], loss:0.4292
# epoch [91/100], loss:0.4272
# epoch [92/100], loss:0.4252
# epoch [93/100], loss:0.4233
# epoch [94/100], loss:0.4214
# epoch [95/100], loss:0.4196
# epoch [96/100], loss:0.4177
# epoch [97/100], loss:0.4158
# epoch [98/100], loss:0.4140
# epoch [99/100], loss:0.4122
# epoch [100/100], loss:0.4104
# 2931

# %%
x_transform = model(inputs)
latent_space = model.encoder(inputs)
print(latent_space.size())
# Out:
# torch.Size([1797, 4, 2, 2])

# %%
plt.plot(n_c_tot,loss_tot)
