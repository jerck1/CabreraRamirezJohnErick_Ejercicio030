# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import sklearn.preprocessing
import torch
import torchvision
import torchvision.datasets
import torchvision.models
import torchvision.transforms

# %%
numeros = sklearn.datasets.load_digits()
imagenes = numeros['images']  # Hay 1797 digitos representados en imagenes 8x8
n_imagenes = len(imagenes)
X = imagenes.copy()
Y = numeros['target']
print(np.shape(X))
# Out:
# (1797, 8, 8)

# %%
inputs = torch.autograd.Variable(torch.Tensor(X).float()).unsqueeze(1)
print(inputs.size())
# Out:
# torch.Size([1797, 1, 8, 8])

# %%
# muestra algunos ejemplos

n_items = inputs.data.size()[0]
random_items = np.random.choice(np.arange(n_items), 5)

plt.figure(figsize=(14,5))
for i in range(5):
    plt.subplot(1,5,i+1)
    item  = random_items[i]
    plt.imshow(inputs[item][0].detach().numpy())
    plt.title(Y[item])

# %%
# normaliza
mean = inputs.mean(dim=0)
std = inputs.std(dim=0)
std[std==0]=1.0

for i in range(len(inputs)):
    inputs[i] = (inputs[i])/std
np.shape(inputs)
# Out:
# torch.Size([1797, 1, 8, 8])

# %%
# define el autoencoder
class Autoencoder(torch.nn.Module):
    def __init__(self):
        super(Autoencoder,self).__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 16, kernel_size=3),
            torch.nn.Conv2d(16,8,kernel_size=3),
            torch.nn.Conv2d(8,4,kernel_size=3))
        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(4,8,kernel_size=3),
            torch.nn.ConvTranspose2d(8,16,kernel_size=3),
            torch.nn.ConvTranspose2d(16,1,kernel_size=3))
    def forward(self,x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# define el autoencoder
class Autoencoder(torch.nn.Module):
    def __init__(self,k1, k2, k3):
        super(Autoencoder,self).__init__()
        #k1=16; k2=8; k3=4
        self.k1=k1
        self.k2=k2
        self.k3=k3
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, k1, kernel_size=3),
            torch.nn.Conv2d(k1,k2,kernel_size=3),
            torch.nn.Conv2d(k2,k3,kernel_size=3))
        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(k3,k2,kernel_size=3),
            torch.nn.ConvTranspose2d(k2,k1,kernel_size=3),
            torch.nn.ConvTranspose2d(k1,1,kernel_size=3))
    def forward(self,x,k1, k2, k3):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# entrenamiento
# inicializa modelo, loss y optimizador
k1=16
k2_tot=[4,8,12]
#k3=4
latent_space=np.linspace(2.,12.,6)
n_c_tot=[]
loss_tot=[]
for k2 in k2_tot:
    for k3 in latent_space:
        num_epochs = 100
        model = Autoencoder(k1,int(k2),int(k3))
        print(model)
        distance = torch.nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=1E-4)
        loss_list = [] 
        for epoch in range(num_epochs):
            output = model(inputs,k1,8,4)
            loss = distance(output, inputs)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_list.append(loss.item())
            #print('epoch [{}/{}], loss:{:.4f}'.format(epoch+1, num_epochs, loss.item()))
        loss_tot.append(loss_list[-1])
        #type(loss.item())
        n_c=0
        for m in model.parameters():
            n_c+=m.flatten().size()[0]
        n_c_tot.append(n_c)
        print(n_c)
# Out:
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 2, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(2, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.4505
# epoch [2/100], loss:2.3610
# epoch [3/100], loss:2.2170
# epoch [4/100], loss:2.0661
# epoch [5/100], loss:1.9105
# epoch [6/100], loss:1.7236
# epoch [7/100], loss:1.5333
# epoch [8/100], loss:1.5055
# epoch [9/100], loss:1.5516
# epoch [10/100], loss:1.4147
# epoch [11/100], loss:1.3023
# epoch [12/100], loss:1.2611
# epoch [13/100], loss:1.2444
# epoch [14/100], loss:1.2235
# epoch [15/100], loss:1.1938
# epoch [16/100], loss:1.1604
# epoch [17/100], loss:1.1305
# epoch [18/100], loss:1.1083
# epoch [19/100], loss:1.0902
# epoch [20/100], loss:1.0681
# epoch [21/100], loss:1.0407
# epoch [22/100], loss:1.0158
# epoch [23/100], loss:1.0016
# epoch [24/100], loss:0.9978
# epoch [25/100], loss:0.9967
# epoch [26/100], loss:0.9934
# epoch [27/100], loss:0.9877
# epoch [28/100], loss:0.9780
# epoch [29/100], loss:0.9632
# epoch [30/100], loss:0.9482
# epoch [31/100], loss:0.9352
# epoch [32/100], loss:0.9226
# epoch [33/100], loss:0.9133
# epoch [34/100], loss:0.9053
# epoch [35/100], loss:0.8967
# epoch [36/100], loss:0.8907
# epoch [37/100], loss:0.8859
# epoch [38/100], loss:0.8828
# epoch [39/100], loss:0.8804
# epoch [40/100], loss:0.8755
# epoch [41/100], loss:0.8698
# epoch [42/100], loss:0.8636
# epoch [43/100], loss:0.8580
# epoch [44/100], loss:0.8535
# epoch [45/100], loss:0.8484
# epoch [46/100], loss:0.8443
# epoch [47/100], loss:0.8408
# epoch [48/100], loss:0.8391
# epoch [49/100], loss:0.8379
# epoch [50/100], loss:0.8366
# epoch [51/100], loss:0.8344
# epoch [52/100], loss:0.8317
# epoch [53/100], loss:0.8286
# epoch [54/100], loss:0.8256
# epoch [55/100], loss:0.8225
# epoch [56/100], loss:0.8196
# epoch [57/100], loss:0.8168
# epoch [58/100], loss:0.8145
# epoch [59/100], loss:0.8124
# epoch [60/100], loss:0.8103
# epoch [61/100], loss:0.8079
# epoch [62/100], loss:0.8055
# epoch [63/100], loss:0.8031
# epoch [64/100], loss:0.8008
# epoch [65/100], loss:0.7984
# epoch [66/100], loss:0.7961
# epoch [67/100], loss:0.7939
# epoch [68/100], loss:0.7917
# epoch [69/100], loss:0.7898
# epoch [70/100], loss:0.7878
# epoch [71/100], loss:0.7858
# epoch [72/100], loss:0.7840
# epoch [73/100], loss:0.7821
# epoch [74/100], loss:0.7803
# epoch [75/100], loss:0.7784
# epoch [76/100], loss:0.7766
# epoch [77/100], loss:0.7749
# epoch [78/100], loss:0.7732
# epoch [79/100], loss:0.7716
# epoch [80/100], loss:0.7701
# epoch [81/100], loss:0.7685
# epoch [82/100], loss:0.7670
# epoch [83/100], loss:0.7655
# epoch [84/100], loss:0.7641
# epoch [85/100], loss:0.7626
# epoch [86/100], loss:0.7612
# epoch [87/100], loss:0.7598
# epoch [88/100], loss:0.7584
# epoch [89/100], loss:0.7571
# epoch [90/100], loss:0.7557
# epoch [91/100], loss:0.7544
# epoch [92/100], loss:0.7532
# epoch [93/100], loss:0.7519
# epoch [94/100], loss:0.7507
# epoch [95/100], loss:0.7494
# epoch [96/100], loss:0.7483
# epoch [97/100], loss:0.7471
# epoch [98/100], loss:0.7460
# epoch [99/100], loss:0.7449
# epoch [100/100], loss:0.7438
# 1627
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(4, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:3.2429
# epoch [2/100], loss:2.9809
# epoch [3/100], loss:2.7198
# epoch [4/100], loss:2.3457
# epoch [5/100], loss:1.9244
# epoch [6/100], loss:1.9258
# epoch [7/100], loss:1.8492
# epoch [8/100], loss:1.6362
# epoch [9/100], loss:1.5646
# epoch [10/100], loss:1.5557
# epoch [11/100], loss:1.5297
# epoch [12/100], loss:1.4733
# epoch [13/100], loss:1.4009
# epoch [14/100], loss:1.3373
# epoch [15/100], loss:1.3039
# epoch [16/100], loss:1.2914
# epoch [17/100], loss:1.2588
# epoch [18/100], loss:1.1983
# epoch [19/100], loss:1.1440
# epoch [20/100], loss:1.1166
# epoch [21/100], loss:1.1077
# epoch [22/100], loss:1.0967
# epoch [23/100], loss:1.0702
# epoch [24/100], loss:1.0322
# epoch [25/100], loss:1.0015
# epoch [26/100], loss:0.9898
# epoch [27/100], loss:0.9810
# epoch [28/100], loss:0.9597
# epoch [29/100], loss:0.9369
# epoch [30/100], loss:0.9246
# epoch [31/100], loss:0.9208
# epoch [32/100], loss:0.9190
# epoch [33/100], loss:0.9143
# epoch [34/100], loss:0.9047
# epoch [35/100], loss:0.8928
# epoch [36/100], loss:0.8847
# epoch [37/100], loss:0.8821
# epoch [38/100], loss:0.8774
# epoch [39/100], loss:0.8670
# epoch [40/100], loss:0.8560
# epoch [41/100], loss:0.8482
# epoch [42/100], loss:0.8414
# epoch [43/100], loss:0.8326
# epoch [44/100], loss:0.8225
# epoch [45/100], loss:0.8131
# epoch [46/100], loss:0.8049
# epoch [47/100], loss:0.7968
# epoch [48/100], loss:0.7878
# epoch [49/100], loss:0.7781
# epoch [50/100], loss:0.7693
# epoch [51/100], loss:0.7625
# epoch [52/100], loss:0.7567
# epoch [53/100], loss:0.7505
# epoch [54/100], loss:0.7432
# epoch [55/100], loss:0.7362
# epoch [56/100], loss:0.7304
# epoch [57/100], loss:0.7257
# epoch [58/100], loss:0.7210
# epoch [59/100], loss:0.7158
# epoch [60/100], loss:0.7107
# epoch [61/100], loss:0.7060
# epoch [62/100], loss:0.7018
# epoch [63/100], loss:0.6977
# epoch [64/100], loss:0.6935
# epoch [65/100], loss:0.6893
# epoch [66/100], loss:0.6854
# epoch [67/100], loss:0.6819
# epoch [68/100], loss:0.6787
# epoch [69/100], loss:0.6755
# epoch [70/100], loss:0.6723
# epoch [71/100], loss:0.6694
# epoch [72/100], loss:0.6668
# epoch [73/100], loss:0.6643
# epoch [74/100], loss:0.6615
# epoch [75/100], loss:0.6585
# epoch [76/100], loss:0.6557
# epoch [77/100], loss:0.6529
# epoch [78/100], loss:0.6503
# epoch [79/100], loss:0.6476
# epoch [80/100], loss:0.6450
# epoch [81/100], loss:0.6425
# epoch [82/100], loss:0.6402
# epoch [83/100], loss:0.6380
# epoch [84/100], loss:0.6357
# epoch [85/100], loss:0.6335
# epoch [86/100], loss:0.6313
# epoch [87/100], loss:0.6292
# epoch [88/100], loss:0.6272
# epoch [89/100], loss:0.6252
# epoch [90/100], loss:0.6232
# epoch [91/100], loss:0.6212
# epoch [92/100], loss:0.6194
# epoch [93/100], loss:0.6176
# epoch [94/100], loss:0.6158
# epoch [95/100], loss:0.6141
# epoch [96/100], loss:0.6124
# epoch [97/100], loss:0.6108
# epoch [98/100], loss:0.6092
# epoch [99/100], loss:0.6076
# epoch [100/100], loss:0.6061
# 1773
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 6, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(6, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.0116
# epoch [2/100], loss:1.8713
# epoch [3/100], loss:1.6665
# epoch [4/100], loss:1.4341
# epoch [5/100], loss:1.5660
# epoch [6/100], loss:1.3136
# epoch [7/100], loss:1.2368
# epoch [8/100], loss:1.2418
# epoch [9/100], loss:1.2315
# epoch [10/100], loss:1.1921
# epoch [11/100], loss:1.1389
# epoch [12/100], loss:1.1053
# epoch [13/100], loss:1.1100
# epoch [14/100], loss:1.0992
# epoch [15/100], loss:1.0486
# epoch [16/100], loss:1.0125
# epoch [17/100], loss:1.0078
# epoch [18/100], loss:1.0120
# epoch [19/100], loss:1.0069
# epoch [20/100], loss:0.9892
# epoch [21/100], loss:0.9668
# epoch [22/100], loss:0.9521
# epoch [23/100], loss:0.9484
# epoch [24/100], loss:0.9416
# epoch [25/100], loss:0.9250
# epoch [26/100], loss:0.9115
# epoch [27/100], loss:0.9071
# epoch [28/100], loss:0.9038
# epoch [29/100], loss:0.8939
# epoch [30/100], loss:0.8777
# epoch [31/100], loss:0.8619
# epoch [32/100], loss:0.8507
# epoch [33/100], loss:0.8401
# epoch [34/100], loss:0.8262
# epoch [35/100], loss:0.8138
# epoch [36/100], loss:0.8069
# epoch [37/100], loss:0.8021
# epoch [38/100], loss:0.7956
# epoch [39/100], loss:0.7893
# epoch [40/100], loss:0.7854
# epoch [41/100], loss:0.7807
# epoch [42/100], loss:0.7733
# epoch [43/100], loss:0.7662
# epoch [44/100], loss:0.7605
# epoch [45/100], loss:0.7542
# epoch [46/100], loss:0.7472
# epoch [47/100], loss:0.7413
# epoch [48/100], loss:0.7368
# epoch [49/100], loss:0.7321
# epoch [50/100], loss:0.7267
# epoch [51/100], loss:0.7219
# epoch [52/100], loss:0.7177
# epoch [53/100], loss:0.7129
# epoch [54/100], loss:0.7075
# epoch [55/100], loss:0.7023
# epoch [56/100], loss:0.6974
# epoch [57/100], loss:0.6925
# epoch [58/100], loss:0.6876
# epoch [59/100], loss:0.6832
# epoch [60/100], loss:0.6791
# epoch [61/100], loss:0.6751
# epoch [62/100], loss:0.6710
# epoch [63/100], loss:0.6669
# epoch [64/100], loss:0.6629
# epoch [65/100], loss:0.6591
# epoch [66/100], loss:0.6554
# epoch [67/100], loss:0.6518
# epoch [68/100], loss:0.6484
# epoch [69/100], loss:0.6450
# epoch [70/100], loss:0.6414
# epoch [71/100], loss:0.6379
# epoch [72/100], loss:0.6346
# epoch [73/100], loss:0.6313
# epoch [74/100], loss:0.6279
# epoch [75/100], loss:0.6245
# epoch [76/100], loss:0.6211
# epoch [77/100], loss:0.6177
# epoch [78/100], loss:0.6145
# epoch [79/100], loss:0.6113
# epoch [80/100], loss:0.6082
# epoch [81/100], loss:0.6054
# epoch [82/100], loss:0.6025
# epoch [83/100], loss:0.5997
# epoch [84/100], loss:0.5968
# epoch [85/100], loss:0.5940
# epoch [86/100], loss:0.5912
# epoch [87/100], loss:0.5885
# epoch [88/100], loss:0.5857
# epoch [89/100], loss:0.5830
# epoch [90/100], loss:0.5804
# epoch [91/100], loss:0.5777
# epoch [92/100], loss:0.5750
# epoch [93/100], loss:0.5723
# epoch [94/100], loss:0.5697
# epoch [95/100], loss:0.5670
# epoch [96/100], loss:0.5643
# epoch [97/100], loss:0.5616
# epoch [98/100], loss:0.5589
# epoch [99/100], loss:0.5563
# epoch [100/100], loss:0.5536
# 1919
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(8, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.4619
# epoch [2/100], loss:2.2457
# epoch [3/100], loss:1.9389
# epoch [4/100], loss:1.6245
# epoch [5/100], loss:1.7318
# epoch [6/100], loss:1.4560
# epoch [7/100], loss:1.3022
# epoch [8/100], loss:1.2879
# epoch [9/100], loss:1.2726
# epoch [10/100], loss:1.2155
# epoch [11/100], loss:1.1348
# epoch [12/100], loss:1.0769
# epoch [13/100], loss:1.0578
# epoch [14/100], loss:1.0197
# epoch [15/100], loss:0.9638
# epoch [16/100], loss:0.9372
# epoch [17/100], loss:0.9312
# epoch [18/100], loss:0.9206
# epoch [19/100], loss:0.9013
# epoch [20/100], loss:0.8828
# epoch [21/100], loss:0.8735
# epoch [22/100], loss:0.8686
# epoch [23/100], loss:0.8549
# epoch [24/100], loss:0.8336
# epoch [25/100], loss:0.8159
# epoch [26/100], loss:0.8056
# epoch [27/100], loss:0.7986
# epoch [28/100], loss:0.7912
# epoch [29/100], loss:0.7836
# epoch [30/100], loss:0.7775
# epoch [31/100], loss:0.7722
# epoch [32/100], loss:0.7653
# epoch [33/100], loss:0.7570
# epoch [34/100], loss:0.7497
# epoch [35/100], loss:0.7433
# epoch [36/100], loss:0.7358
# epoch [37/100], loss:0.7267
# epoch [38/100], loss:0.7181
# epoch [39/100], loss:0.7122
# epoch [40/100], loss:0.7080
# epoch [41/100], loss:0.7034
# epoch [42/100], loss:0.6976
# epoch [43/100], loss:0.6917
# epoch [44/100], loss:0.6864
# epoch [45/100], loss:0.6813
# epoch [46/100], loss:0.6766
# epoch [47/100], loss:0.6723
# epoch [48/100], loss:0.6683
# epoch [49/100], loss:0.6638
# epoch [50/100], loss:0.6587
# epoch [51/100], loss:0.6542
# epoch [52/100], loss:0.6507
# epoch [53/100], loss:0.6472
# epoch [54/100], loss:0.6434
# epoch [55/100], loss:0.6395
# epoch [56/100], loss:0.6360
# epoch [57/100], loss:0.6323
# epoch [58/100], loss:0.6284
# epoch [59/100], loss:0.6247
# epoch [60/100], loss:0.6213
# epoch [61/100], loss:0.6178
# epoch [62/100], loss:0.6142
# epoch [63/100], loss:0.6107
# epoch [64/100], loss:0.6072
# epoch [65/100], loss:0.6035
# epoch [66/100], loss:0.5998
# epoch [67/100], loss:0.5962
# epoch [68/100], loss:0.5925
# epoch [69/100], loss:0.5887
# epoch [70/100], loss:0.5848
# epoch [71/100], loss:0.5811
# epoch [72/100], loss:0.5773
# epoch [73/100], loss:0.5736
# epoch [74/100], loss:0.5699
# epoch [75/100], loss:0.5664
# epoch [76/100], loss:0.5628
# epoch [77/100], loss:0.5592
# epoch [78/100], loss:0.5557
# epoch [79/100], loss:0.5525
# epoch [80/100], loss:0.5492
# epoch [81/100], loss:0.5460
# epoch [82/100], loss:0.5429
# epoch [83/100], loss:0.5399
# epoch [84/100], loss:0.5369
# epoch [85/100], loss:0.5339
# epoch [86/100], loss:0.5311
# epoch [87/100], loss:0.5283
# epoch [88/100], loss:0.5257
# epoch [89/100], loss:0.5231
# epoch [90/100], loss:0.5205
# epoch [91/100], loss:0.5180
# epoch [92/100], loss:0.5156
# epoch [93/100], loss:0.5132
# epoch [94/100], loss:0.5107
# epoch [95/100], loss:0.5083
# epoch [96/100], loss:0.5059
# epoch [97/100], loss:0.5035
# epoch [98/100], loss:0.5011
# epoch [99/100], loss:0.4987
# epoch [100/100], loss:0.4963
# 2065
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 10, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(10, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.9743
# epoch [2/100], loss:2.6294
# epoch [3/100], loss:2.1411
# epoch [4/100], loss:1.7186
# epoch [5/100], loss:2.1509
# epoch [6/100], loss:1.5944
# epoch [7/100], loss:1.5061
# epoch [8/100], loss:1.5713
# epoch [9/100], loss:1.5625
# epoch [10/100], loss:1.4825
# epoch [11/100], loss:1.3703
# epoch [12/100], loss:1.2614
# epoch [13/100], loss:1.1977
# epoch [14/100], loss:1.2079
# epoch [15/100], loss:1.2196
# epoch [16/100], loss:1.1520
# epoch [17/100], loss:1.0758
# epoch [18/100], loss:1.0507
# epoch [19/100], loss:1.0546
# epoch [20/100], loss:1.0517
# epoch [21/100], loss:1.0296
# epoch [22/100], loss:0.9978
# epoch [23/100], loss:0.9741
# epoch [24/100], loss:0.9662
# epoch [25/100], loss:0.9572
# epoch [26/100], loss:0.9308
# epoch [27/100], loss:0.9001
# epoch [28/100], loss:0.8834
# epoch [29/100], loss:0.8779
# epoch [30/100], loss:0.8701
# epoch [31/100], loss:0.8551
# epoch [32/100], loss:0.8394
# epoch [33/100], loss:0.8311
# epoch [34/100], loss:0.8278
# epoch [35/100], loss:0.8202
# epoch [36/100], loss:0.8076
# epoch [37/100], loss:0.7984
# epoch [38/100], loss:0.7934
# epoch [39/100], loss:0.7850
# epoch [40/100], loss:0.7729
# epoch [41/100], loss:0.7652
# epoch [42/100], loss:0.7624
# epoch [43/100], loss:0.7571
# epoch [44/100], loss:0.7491
# epoch [45/100], loss:0.7437
# epoch [46/100], loss:0.7399
# epoch [47/100], loss:0.7336
# epoch [48/100], loss:0.7265
# epoch [49/100], loss:0.7219
# epoch [50/100], loss:0.7176
# epoch [51/100], loss:0.7114
# epoch [52/100], loss:0.7053
# epoch [53/100], loss:0.7005
# epoch [54/100], loss:0.6955
# epoch [55/100], loss:0.6896
# epoch [56/100], loss:0.6847
# epoch [57/100], loss:0.6810
# epoch [58/100], loss:0.6768
# epoch [59/100], loss:0.6721
# epoch [60/100], loss:0.6680
# epoch [61/100], loss:0.6640
# epoch [62/100], loss:0.6593
# epoch [63/100], loss:0.6547
# epoch [64/100], loss:0.6509
# epoch [65/100], loss:0.6471
# epoch [66/100], loss:0.6429
# epoch [67/100], loss:0.6388
# epoch [68/100], loss:0.6350
# epoch [69/100], loss:0.6309
# epoch [70/100], loss:0.6269
# epoch [71/100], loss:0.6232
# epoch [72/100], loss:0.6195
# epoch [73/100], loss:0.6156
# epoch [74/100], loss:0.6116
# epoch [75/100], loss:0.6076
# epoch [76/100], loss:0.6036
# epoch [77/100], loss:0.5993
# epoch [78/100], loss:0.5949
# epoch [79/100], loss:0.5904
# epoch [80/100], loss:0.5858
# epoch [81/100], loss:0.5812
# epoch [82/100], loss:0.5766
# epoch [83/100], loss:0.5719
# epoch [84/100], loss:0.5670
# epoch [85/100], loss:0.5621
# epoch [86/100], loss:0.5570
# epoch [87/100], loss:0.5519
# epoch [88/100], loss:0.5469
# epoch [89/100], loss:0.5417
# epoch [90/100], loss:0.5366
# epoch [91/100], loss:0.5316
# epoch [92/100], loss:0.5267
# epoch [93/100], loss:0.5219
# epoch [94/100], loss:0.5172
# epoch [95/100], loss:0.5128
# epoch [96/100], loss:0.5086
# epoch [97/100], loss:0.5048
# epoch [98/100], loss:0.5011
# epoch [99/100], loss:0.4977
# epoch [100/100], loss:0.4944
# 2211
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(4, 12, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(12, 4, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(4, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:1.8357
# epoch [2/100], loss:1.6435
# epoch [3/100], loss:1.4445
# epoch [4/100], loss:1.5390
# epoch [5/100], loss:1.3253
# epoch [6/100], loss:1.3439
# epoch [7/100], loss:1.3269
# epoch [8/100], loss:1.2409
# epoch [9/100], loss:1.1369
# epoch [10/100], loss:1.0946
# epoch [11/100], loss:1.1031
# epoch [12/100], loss:1.0441
# epoch [13/100], loss:1.0045
# epoch [14/100], loss:0.9989
# epoch [15/100], loss:0.9902
# epoch [16/100], loss:0.9712
# epoch [17/100], loss:0.9465
# epoch [18/100], loss:0.9231
# epoch [19/100], loss:0.9061
# epoch [20/100], loss:0.8918
# epoch [21/100], loss:0.8749
# epoch [22/100], loss:0.8589
# epoch [23/100], loss:0.8505
# epoch [24/100], loss:0.8481
# epoch [25/100], loss:0.8430
# epoch [26/100], loss:0.8283
# epoch [27/100], loss:0.8069
# epoch [28/100], loss:0.7861
# epoch [29/100], loss:0.7703
# epoch [30/100], loss:0.7592
# epoch [31/100], loss:0.7487
# epoch [32/100], loss:0.7362
# epoch [33/100], loss:0.7232
# epoch [34/100], loss:0.7128
# epoch [35/100], loss:0.7049
# epoch [36/100], loss:0.6971
# epoch [37/100], loss:0.6878
# epoch [38/100], loss:0.6780
# epoch [39/100], loss:0.6697
# epoch [40/100], loss:0.6627
# epoch [41/100], loss:0.6551
# epoch [42/100], loss:0.6463
# epoch [43/100], loss:0.6373
# epoch [44/100], loss:0.6298
# epoch [45/100], loss:0.6237
# epoch [46/100], loss:0.6179
# epoch [47/100], loss:0.6115
# epoch [48/100], loss:0.6050
# epoch [49/100], loss:0.5994
# epoch [50/100], loss:0.5943
# epoch [51/100], loss:0.5890
# epoch [52/100], loss:0.5838
# epoch [53/100], loss:0.5790
# epoch [54/100], loss:0.5745
# epoch [55/100], loss:0.5698
# epoch [56/100], loss:0.5652
# epoch [57/100], loss:0.5610
# epoch [58/100], loss:0.5570
# epoch [59/100], loss:0.5526
# epoch [60/100], loss:0.5481
# epoch [61/100], loss:0.5439
# epoch [62/100], loss:0.5398
# epoch [63/100], loss:0.5358
# epoch [64/100], loss:0.5319
# epoch [65/100], loss:0.5281
# epoch [66/100], loss:0.5241
# epoch [67/100], loss:0.5201
# epoch [68/100], loss:0.5163
# epoch [69/100], loss:0.5125
# epoch [70/100], loss:0.5089
# epoch [71/100], loss:0.5054
# epoch [72/100], loss:0.5019
# epoch [73/100], loss:0.4983
# epoch [74/100], loss:0.4948
# epoch [75/100], loss:0.4913
# epoch [76/100], loss:0.4879
# epoch [77/100], loss:0.4845
# epoch [78/100], loss:0.4812
# epoch [79/100], loss:0.4779
# epoch [80/100], loss:0.4747
# epoch [81/100], loss:0.4715
# epoch [82/100], loss:0.4683
# epoch [83/100], loss:0.4652
# epoch [84/100], loss:0.4621
# epoch [85/100], loss:0.4592
# epoch [86/100], loss:0.4563
# epoch [87/100], loss:0.4534
# epoch [88/100], loss:0.4506
# epoch [89/100], loss:0.4478
# epoch [90/100], loss:0.4451
# epoch [91/100], loss:0.4424
# epoch [92/100], loss:0.4397
# epoch [93/100], loss:0.4371
# epoch [94/100], loss:0.4345
# epoch [95/100], loss:0.4319
# epoch [96/100], loss:0.4294
# epoch [97/100], loss:0.4268
# epoch [98/100], loss:0.4243
# epoch [99/100], loss:0.4217
# epoch [100/100], loss:0.4192
# 2357
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 2, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(2, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.8299
# epoch [2/100], loss:2.6347
# epoch [3/100], loss:2.3006
# epoch [4/100], loss:1.8895
# epoch [5/100], loss:1.9492
# epoch [6/100], loss:1.5582
# epoch [7/100], loss:1.4481
# epoch [8/100], loss:1.4399
# epoch [9/100], loss:1.3703
# epoch [10/100], loss:1.2742
# epoch [11/100], loss:1.2493
# epoch [12/100], loss:1.2527
# epoch [13/100], loss:1.1654
# epoch [14/100], loss:1.1044
# epoch [15/100], loss:1.1089
# epoch [16/100], loss:1.1104
# epoch [17/100], loss:1.0794
# epoch [18/100], loss:1.0441
# epoch [19/100], loss:1.0352
# epoch [20/100], loss:1.0309
# epoch [21/100], loss:1.0039
# epoch [22/100], loss:0.9816
# epoch [23/100], loss:0.9797
# epoch [24/100], loss:0.9811
# epoch [25/100], loss:0.9716
# epoch [26/100], loss:0.9557
# epoch [27/100], loss:0.9466
# epoch [28/100], loss:0.9454
# epoch [29/100], loss:0.9390
# epoch [30/100], loss:0.9262
# epoch [31/100], loss:0.9174
# epoch [32/100], loss:0.9133
# epoch [33/100], loss:0.9074
# epoch [34/100], loss:0.8980
# epoch [35/100], loss:0.8887
# epoch [36/100], loss:0.8820
# epoch [37/100], loss:0.8759
# epoch [38/100], loss:0.8694
# epoch [39/100], loss:0.8643
# epoch [40/100], loss:0.8593
# epoch [41/100], loss:0.8536
# epoch [42/100], loss:0.8489
# epoch [43/100], loss:0.8450
# epoch [44/100], loss:0.8399
# epoch [45/100], loss:0.8352
# epoch [46/100], loss:0.8322
# epoch [47/100], loss:0.8284
# epoch [48/100], loss:0.8242
# epoch [49/100], loss:0.8215
# epoch [50/100], loss:0.8191
# epoch [51/100], loss:0.8158
# epoch [52/100], loss:0.8130
# epoch [53/100], loss:0.8109
# epoch [54/100], loss:0.8082
# epoch [55/100], loss:0.8052
# epoch [56/100], loss:0.8030
# epoch [57/100], loss:0.8009
# epoch [58/100], loss:0.7983
# epoch [59/100], loss:0.7960
# epoch [60/100], loss:0.7943
# epoch [61/100], loss:0.7922
# epoch [62/100], loss:0.7901
# epoch [63/100], loss:0.7884
# epoch [64/100], loss:0.7869
# epoch [65/100], loss:0.7851
# epoch [66/100], loss:0.7835
# epoch [67/100], loss:0.7823
# epoch [68/100], loss:0.7808
# epoch [69/100], loss:0.7793
# epoch [70/100], loss:0.7780
# epoch [71/100], loss:0.7767
# epoch [72/100], loss:0.7753
# epoch [73/100], loss:0.7740
# epoch [74/100], loss:0.7729
# epoch [75/100], loss:0.7716
# epoch [76/100], loss:0.7703
# epoch [77/100], loss:0.7692
# epoch [78/100], loss:0.7682
# epoch [79/100], loss:0.7670
# epoch [80/100], loss:0.7659
# epoch [81/100], loss:0.7649
# epoch [82/100], loss:0.7639
# epoch [83/100], loss:0.7628
# epoch [84/100], loss:0.7619
# epoch [85/100], loss:0.7609
# epoch [86/100], loss:0.7599
# epoch [87/100], loss:0.7590
# epoch [88/100], loss:0.7581
# epoch [89/100], loss:0.7571
# epoch [90/100], loss:0.7562
# epoch [91/100], loss:0.7554
# epoch [92/100], loss:0.7545
# epoch [93/100], loss:0.7536
# epoch [94/100], loss:0.7528
# epoch [95/100], loss:0.7520
# epoch [96/100], loss:0.7512
# epoch [97/100], loss:0.7504
# epoch [98/100], loss:0.7497
# epoch [99/100], loss:0.7489
# epoch [100/100], loss:0.7481
# 2931
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(4, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.4097
# epoch [2/100], loss:2.0722
# epoch [3/100], loss:1.5424
# epoch [4/100], loss:1.8061
# epoch [5/100], loss:1.2990
# epoch [6/100], loss:1.2463
# epoch [7/100], loss:1.3104
# epoch [8/100], loss:1.2973
# epoch [9/100], loss:1.2052
# epoch [10/100], loss:1.0889
# epoch [11/100], loss:1.0367
# epoch [12/100], loss:1.0778
# epoch [13/100], loss:1.0694
# epoch [14/100], loss:1.0016
# epoch [15/100], loss:0.9771
# epoch [16/100], loss:0.9939
# epoch [17/100], loss:1.0093
# epoch [18/100], loss:1.0017
# epoch [19/100], loss:0.9719
# epoch [20/100], loss:0.9346
# epoch [21/100], loss:0.9097
# epoch [22/100], loss:0.9051
# epoch [23/100], loss:0.9015
# epoch [24/100], loss:0.8806
# epoch [25/100], loss:0.8570
# epoch [26/100], loss:0.8487
# epoch [27/100], loss:0.8524
# epoch [28/100], loss:0.8558
# epoch [29/100], loss:0.8526
# epoch [30/100], loss:0.8444
# epoch [31/100], loss:0.8373
# epoch [32/100], loss:0.8335
# epoch [33/100], loss:0.8286
# epoch [34/100], loss:0.8188
# epoch [35/100], loss:0.8081
# epoch [36/100], loss:0.8024
# epoch [37/100], loss:0.8010
# epoch [38/100], loss:0.7992
# epoch [39/100], loss:0.7947
# epoch [40/100], loss:0.7890
# epoch [41/100], loss:0.7850
# epoch [42/100], loss:0.7817
# epoch [43/100], loss:0.7762
# epoch [44/100], loss:0.7689
# epoch [45/100], loss:0.7634
# epoch [46/100], loss:0.7605
# epoch [47/100], loss:0.7577
# epoch [48/100], loss:0.7534
# epoch [49/100], loss:0.7494
# epoch [50/100], loss:0.7461
# epoch [51/100], loss:0.7419
# epoch [52/100], loss:0.7370
# epoch [53/100], loss:0.7327
# epoch [54/100], loss:0.7284
# epoch [55/100], loss:0.7236
# epoch [56/100], loss:0.7193
# epoch [57/100], loss:0.7158
# epoch [58/100], loss:0.7118
# epoch [59/100], loss:0.7070
# epoch [60/100], loss:0.7024
# epoch [61/100], loss:0.6982
# epoch [62/100], loss:0.6935
# epoch [63/100], loss:0.6884
# epoch [64/100], loss:0.6837
# epoch [65/100], loss:0.6793
# epoch [66/100], loss:0.6747
# epoch [67/100], loss:0.6699
# epoch [68/100], loss:0.6651
# epoch [69/100], loss:0.6601
# epoch [70/100], loss:0.6549
# epoch [71/100], loss:0.6500
# epoch [72/100], loss:0.6452
# epoch [73/100], loss:0.6405
# epoch [74/100], loss:0.6361
# epoch [75/100], loss:0.6322
# epoch [76/100], loss:0.6284
# epoch [77/100], loss:0.6251
# epoch [78/100], loss:0.6221
# epoch [79/100], loss:0.6193
# epoch [80/100], loss:0.6166
# epoch [81/100], loss:0.6141
# epoch [82/100], loss:0.6115
# epoch [83/100], loss:0.6090
# epoch [84/100], loss:0.6067
# epoch [85/100], loss:0.6043
# epoch [86/100], loss:0.6020
# epoch [87/100], loss:0.5998
# epoch [88/100], loss:0.5975
# epoch [89/100], loss:0.5953
# epoch [90/100], loss:0.5931
# epoch [91/100], loss:0.5910
# epoch [92/100], loss:0.5890
# epoch [93/100], loss:0.5871
# epoch [94/100], loss:0.5853
# epoch [95/100], loss:0.5837
# epoch [96/100], loss:0.5821
# epoch [97/100], loss:0.5806
# epoch [98/100], loss:0.5791
# epoch [99/100], loss:0.5777
# epoch [100/100], loss:0.5763
# 3221
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 6, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(6, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:3.0339
# epoch [2/100], loss:2.7156
# epoch [3/100], loss:2.2300
# epoch [4/100], loss:1.8463
# epoch [5/100], loss:1.7401
# epoch [6/100], loss:1.4472
# epoch [7/100], loss:1.4488
# epoch [8/100], loss:1.3616
# epoch [9/100], loss:1.2647
# epoch [10/100], loss:1.2315
# epoch [11/100], loss:1.1267
# epoch [12/100], loss:1.0563
# epoch [13/100], loss:1.0689
# epoch [14/100], loss:1.0781
# epoch [15/100], loss:1.0555
# epoch [16/100], loss:1.0266
# epoch [17/100], loss:1.0021
# epoch [18/100], loss:0.9670
# epoch [19/100], loss:0.9334
# epoch [20/100], loss:0.9176
# epoch [21/100], loss:0.9088
# epoch [22/100], loss:0.8939
# epoch [23/100], loss:0.8770
# epoch [24/100], loss:0.8672
# epoch [25/100], loss:0.8565
# epoch [26/100], loss:0.8370
# epoch [27/100], loss:0.8193
# epoch [28/100], loss:0.8066
# epoch [29/100], loss:0.7911
# epoch [30/100], loss:0.7739
# epoch [31/100], loss:0.7605
# epoch [32/100], loss:0.7487
# epoch [33/100], loss:0.7348
# epoch [34/100], loss:0.7218
# epoch [35/100], loss:0.7115
# epoch [36/100], loss:0.7014
# epoch [37/100], loss:0.6905
# epoch [38/100], loss:0.6803
# epoch [39/100], loss:0.6715
# epoch [40/100], loss:0.6636
# epoch [41/100], loss:0.6549
# epoch [42/100], loss:0.6464
# epoch [43/100], loss:0.6392
# epoch [44/100], loss:0.6318
# epoch [45/100], loss:0.6245
# epoch [46/100], loss:0.6171
# epoch [47/100], loss:0.6105
# epoch [48/100], loss:0.6038
# epoch [49/100], loss:0.5970
# epoch [50/100], loss:0.5903
# epoch [51/100], loss:0.5847
# epoch [52/100], loss:0.5792
# epoch [53/100], loss:0.5742
# epoch [54/100], loss:0.5698
# epoch [55/100], loss:0.5660
# epoch [56/100], loss:0.5620
# epoch [57/100], loss:0.5583
# epoch [58/100], loss:0.5550
# epoch [59/100], loss:0.5518
# epoch [60/100], loss:0.5483
# epoch [61/100], loss:0.5450
# epoch [62/100], loss:0.5417
# epoch [63/100], loss:0.5386
# epoch [64/100], loss:0.5356
# epoch [65/100], loss:0.5328
# epoch [66/100], loss:0.5303
# epoch [67/100], loss:0.5277
# epoch [68/100], loss:0.5253
# epoch [69/100], loss:0.5229
# epoch [70/100], loss:0.5206
# epoch [71/100], loss:0.5185
# epoch [72/100], loss:0.5166
# epoch [73/100], loss:0.5146
# epoch [74/100], loss:0.5127
# epoch [75/100], loss:0.5108
# epoch [76/100], loss:0.5090
# epoch [77/100], loss:0.5070
# epoch [78/100], loss:0.5052
# epoch [79/100], loss:0.5033
# epoch [80/100], loss:0.5015
# epoch [81/100], loss:0.4999
# epoch [82/100], loss:0.4982
# epoch [83/100], loss:0.4966
# epoch [84/100], loss:0.4951
# epoch [85/100], loss:0.4936
# epoch [86/100], loss:0.4920
# epoch [87/100], loss:0.4905
# epoch [88/100], loss:0.4891
# epoch [89/100], loss:0.4876
# epoch [90/100], loss:0.4862
# epoch [91/100], loss:0.4848
# epoch [92/100], loss:0.4835
# epoch [93/100], loss:0.4822
# epoch [94/100], loss:0.4809
# epoch [95/100], loss:0.4796
# epoch [96/100], loss:0.4783
# epoch [97/100], loss:0.4771
# epoch [98/100], loss:0.4759
# epoch [99/100], loss:0.4746
# epoch [100/100], loss:0.4734
# 3511
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.4037
# epoch [2/100], loss:1.9648
# epoch [3/100], loss:1.5473
# epoch [4/100], loss:1.7717
# epoch [5/100], loss:1.3079
# epoch [6/100], loss:1.4129
# epoch [7/100], loss:1.4179
# epoch [8/100], loss:1.3073
# epoch [9/100], loss:1.1740
# epoch [10/100], loss:1.1126
# epoch [11/100], loss:1.1425
# epoch [12/100], loss:1.0979
# epoch [13/100], loss:1.0238
# epoch [14/100], loss:1.0209
# epoch [15/100], loss:1.0432
# epoch [16/100], loss:1.0414
# epoch [17/100], loss:1.0108
# epoch [18/100], loss:0.9737
# epoch [19/100], loss:0.9493
# epoch [20/100], loss:0.9282
# epoch [21/100], loss:0.9001
# epoch [22/100], loss:0.8820
# epoch [23/100], loss:0.8765
# epoch [24/100], loss:0.8660
# epoch [25/100], loss:0.8453
# epoch [26/100], loss:0.8278
# epoch [27/100], loss:0.8255
# epoch [28/100], loss:0.8263
# epoch [29/100], loss:0.8148
# epoch [30/100], loss:0.8022
# epoch [31/100], loss:0.7970
# epoch [32/100], loss:0.7889
# epoch [33/100], loss:0.7762
# epoch [34/100], loss:0.7681
# epoch [35/100], loss:0.7669
# epoch [36/100], loss:0.7644
# epoch [37/100], loss:0.7556
# epoch [38/100], loss:0.7459
# epoch [39/100], loss:0.7401
# epoch [40/100], loss:0.7345
# epoch [41/100], loss:0.7258
# epoch [42/100], loss:0.7171
# epoch [43/100], loss:0.7111
# epoch [44/100], loss:0.7051
# epoch [45/100], loss:0.6976
# epoch [46/100], loss:0.6916
# epoch [47/100], loss:0.6870
# epoch [48/100], loss:0.6804
# epoch [49/100], loss:0.6724
# epoch [50/100], loss:0.6660
# epoch [51/100], loss:0.6603
# epoch [52/100], loss:0.6536
# epoch [53/100], loss:0.6466
# epoch [54/100], loss:0.6398
# epoch [55/100], loss:0.6325
# epoch [56/100], loss:0.6246
# epoch [57/100], loss:0.6166
# epoch [58/100], loss:0.6088
# epoch [59/100], loss:0.6007
# epoch [60/100], loss:0.5924
# epoch [61/100], loss:0.5843
# epoch [62/100], loss:0.5766
# epoch [63/100], loss:0.5684
# epoch [64/100], loss:0.5603
# epoch [65/100], loss:0.5530
# epoch [66/100], loss:0.5465
# epoch [67/100], loss:0.5406
# epoch [68/100], loss:0.5354
# epoch [69/100], loss:0.5305
# epoch [70/100], loss:0.5258
# epoch [71/100], loss:0.5210
# epoch [72/100], loss:0.5159
# epoch [73/100], loss:0.5111
# epoch [74/100], loss:0.5065
# epoch [75/100], loss:0.5020
# epoch [76/100], loss:0.4978
# epoch [77/100], loss:0.4937
# epoch [78/100], loss:0.4900
# epoch [79/100], loss:0.4862
# epoch [80/100], loss:0.4825
# epoch [81/100], loss:0.4789
# epoch [82/100], loss:0.4753
# epoch [83/100], loss:0.4719
# epoch [84/100], loss:0.4685
# epoch [85/100], loss:0.4653
# epoch [86/100], loss:0.4623
# epoch [87/100], loss:0.4594
# epoch [88/100], loss:0.4567
# epoch [89/100], loss:0.4541
# epoch [90/100], loss:0.4515
# epoch [91/100], loss:0.4489
# epoch [92/100], loss:0.4463
# epoch [93/100], loss:0.4438
# epoch [94/100], loss:0.4413
# epoch [95/100], loss:0.4390
# epoch [96/100], loss:0.4368
# epoch [97/100], loss:0.4347
# epoch [98/100], loss:0.4326
# epoch [99/100], loss:0.4306
# epoch [100/100], loss:0.4286
# 3801
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 10, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(10, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.1345
# epoch [2/100], loss:1.9297
# epoch [3/100], loss:1.6772
# epoch [4/100], loss:1.4278
# epoch [5/100], loss:1.5498
# epoch [6/100], loss:1.2517
# epoch [7/100], loss:1.2993
# epoch [8/100], loss:1.2403
# epoch [9/100], loss:1.1208
# epoch [10/100], loss:1.0635
# epoch [11/100], loss:1.0441
# epoch [12/100], loss:0.9830
# epoch [13/100], loss:0.9433
# epoch [14/100], loss:0.9472
# epoch [15/100], loss:0.9254
# epoch [16/100], loss:0.8909
# epoch [17/100], loss:0.8737
# epoch [18/100], loss:0.8657
# epoch [19/100], loss:0.8510
# epoch [20/100], loss:0.8300
# epoch [21/100], loss:0.8099
# epoch [22/100], loss:0.7950
# epoch [23/100], loss:0.7885
# epoch [24/100], loss:0.7865
# epoch [25/100], loss:0.7801
# epoch [26/100], loss:0.7650
# epoch [27/100], loss:0.7457
# epoch [28/100], loss:0.7306
# epoch [29/100], loss:0.7220
# epoch [30/100], loss:0.7154
# epoch [31/100], loss:0.7078
# epoch [32/100], loss:0.6990
# epoch [33/100], loss:0.6883
# epoch [34/100], loss:0.6765
# epoch [35/100], loss:0.6667
# epoch [36/100], loss:0.6599
# epoch [37/100], loss:0.6524
# epoch [38/100], loss:0.6425
# epoch [39/100], loss:0.6334
# epoch [40/100], loss:0.6256
# epoch [41/100], loss:0.6169
# epoch [42/100], loss:0.6077
# epoch [43/100], loss:0.5993
# epoch [44/100], loss:0.5906
# epoch [45/100], loss:0.5816
# epoch [46/100], loss:0.5741
# epoch [47/100], loss:0.5676
# epoch [48/100], loss:0.5606
# epoch [49/100], loss:0.5544
# epoch [50/100], loss:0.5487
# epoch [51/100], loss:0.5425
# epoch [52/100], loss:0.5368
# epoch [53/100], loss:0.5306
# epoch [54/100], loss:0.5240
# epoch [55/100], loss:0.5186
# epoch [56/100], loss:0.5137
# epoch [57/100], loss:0.5089
# epoch [58/100], loss:0.5042
# epoch [59/100], loss:0.4990
# epoch [60/100], loss:0.4945
# epoch [61/100], loss:0.4903
# epoch [62/100], loss:0.4856
# epoch [63/100], loss:0.4815
# epoch [64/100], loss:0.4774
# epoch [65/100], loss:0.4739
# epoch [66/100], loss:0.4701
# epoch [67/100], loss:0.4664
# epoch [68/100], loss:0.4630
# epoch [69/100], loss:0.4596
# epoch [70/100], loss:0.4564
# epoch [71/100], loss:0.4530
# epoch [72/100], loss:0.4501
# epoch [73/100], loss:0.4471
# epoch [74/100], loss:0.4442
# epoch [75/100], loss:0.4414
# epoch [76/100], loss:0.4387
# epoch [77/100], loss:0.4360
# epoch [78/100], loss:0.4334
# epoch [79/100], loss:0.4309
# epoch [80/100], loss:0.4285
# epoch [81/100], loss:0.4261
# epoch [82/100], loss:0.4238
# epoch [83/100], loss:0.4216
# epoch [84/100], loss:0.4193
# epoch [85/100], loss:0.4171
# epoch [86/100], loss:0.4149
# epoch [87/100], loss:0.4127
# epoch [88/100], loss:0.4105
# epoch [89/100], loss:0.4083
# epoch [90/100], loss:0.4062
# epoch [91/100], loss:0.4041
# epoch [92/100], loss:0.4020
# epoch [93/100], loss:0.3999
# epoch [94/100], loss:0.3979
# epoch [95/100], loss:0.3958
# epoch [96/100], loss:0.3938
# epoch [97/100], loss:0.3918
# epoch [98/100], loss:0.3897
# epoch [99/100], loss:0.3877
# epoch [100/100], loss:0.3857
# 4091
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(8, 12, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(12, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:3.0042
# epoch [2/100], loss:2.4690
# epoch [3/100], loss:1.9027
# epoch [4/100], loss:2.1820
# epoch [5/100], loss:1.5817
# epoch [6/100], loss:1.6579
# epoch [7/100], loss:1.6240
# epoch [8/100], loss:1.4280
# epoch [9/100], loss:1.2112
# epoch [10/100], loss:1.2341
# epoch [11/100], loss:1.2432
# epoch [12/100], loss:1.0992
# epoch [13/100], loss:1.0929
# epoch [14/100], loss:1.1407
# epoch [15/100], loss:1.1393
# epoch [16/100], loss:1.0784
# epoch [17/100], loss:1.0078
# epoch [18/100], loss:0.9824
# epoch [19/100], loss:0.9815
# epoch [20/100], loss:0.9476
# epoch [21/100], loss:0.9118
# epoch [22/100], loss:0.9047
# epoch [23/100], loss:0.9049
# epoch [24/100], loss:0.8893
# epoch [25/100], loss:0.8587
# epoch [26/100], loss:0.8315
# epoch [27/100], loss:0.8223
# epoch [28/100], loss:0.8200
# epoch [29/100], loss:0.8078
# epoch [30/100], loss:0.7930
# epoch [31/100], loss:0.7847
# epoch [32/100], loss:0.7777
# epoch [33/100], loss:0.7645
# epoch [34/100], loss:0.7467
# epoch [35/100], loss:0.7329
# epoch [36/100], loss:0.7257
# epoch [37/100], loss:0.7164
# epoch [38/100], loss:0.7017
# epoch [39/100], loss:0.6894
# epoch [40/100], loss:0.6814
# epoch [41/100], loss:0.6727
# epoch [42/100], loss:0.6610
# epoch [43/100], loss:0.6498
# epoch [44/100], loss:0.6418
# epoch [45/100], loss:0.6340
# epoch [46/100], loss:0.6251
# epoch [47/100], loss:0.6179
# epoch [48/100], loss:0.6125
# epoch [49/100], loss:0.6056
# epoch [50/100], loss:0.5966
# epoch [51/100], loss:0.5884
# epoch [52/100], loss:0.5820
# epoch [53/100], loss:0.5752
# epoch [54/100], loss:0.5681
# epoch [55/100], loss:0.5621
# epoch [56/100], loss:0.5567
# epoch [57/100], loss:0.5508
# epoch [58/100], loss:0.5447
# epoch [59/100], loss:0.5389
# epoch [60/100], loss:0.5334
# epoch [61/100], loss:0.5282
# epoch [62/100], loss:0.5233
# epoch [63/100], loss:0.5189
# epoch [64/100], loss:0.5148
# epoch [65/100], loss:0.5105
# epoch [66/100], loss:0.5062
# epoch [67/100], loss:0.5022
# epoch [68/100], loss:0.4981
# epoch [69/100], loss:0.4939
# epoch [70/100], loss:0.4899
# epoch [71/100], loss:0.4861
# epoch [72/100], loss:0.4825
# epoch [73/100], loss:0.4788
# epoch [74/100], loss:0.4751
# epoch [75/100], loss:0.4715
# epoch [76/100], loss:0.4679
# epoch [77/100], loss:0.4644
# epoch [78/100], loss:0.4609
# epoch [79/100], loss:0.4574
# epoch [80/100], loss:0.4540
# epoch [81/100], loss:0.4507
# epoch [82/100], loss:0.4473
# epoch [83/100], loss:0.4439
# epoch [84/100], loss:0.4406
# epoch [85/100], loss:0.4374
# epoch [86/100], loss:0.4343
# epoch [87/100], loss:0.4312
# epoch [88/100], loss:0.4280
# epoch [89/100], loss:0.4249
# epoch [90/100], loss:0.4219
# epoch [91/100], loss:0.4189
# epoch [92/100], loss:0.4159
# epoch [93/100], loss:0.4130
# epoch [94/100], loss:0.4101
# epoch [95/100], loss:0.4072
# epoch [96/100], loss:0.4044
# epoch [97/100], loss:0.4016
# epoch [98/100], loss:0.3989
# epoch [99/100], loss:0.3963
# epoch [100/100], loss:0.3936
# 4381
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 2, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(2, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.6973
# epoch [2/100], loss:2.5118
# epoch [3/100], loss:2.1700
# epoch [4/100], loss:1.6568
# epoch [5/100], loss:1.7678
# epoch [6/100], loss:1.3783
# epoch [7/100], loss:1.2623
# epoch [8/100], loss:1.2780
# epoch [9/100], loss:1.2450
# epoch [10/100], loss:1.1759
# epoch [11/100], loss:1.1289
# epoch [12/100], loss:1.1267
# epoch [13/100], loss:1.0994
# epoch [14/100], loss:1.0455
# epoch [15/100], loss:1.0319
# epoch [16/100], loss:1.0454
# epoch [17/100], loss:1.0394
# epoch [18/100], loss:1.0086
# epoch [19/100], loss:0.9795
# epoch [20/100], loss:0.9746
# epoch [21/100], loss:0.9807
# epoch [22/100], loss:0.9707
# epoch [23/100], loss:0.9530
# epoch [24/100], loss:0.9459
# epoch [25/100], loss:0.9455
# epoch [26/100], loss:0.9402
# epoch [27/100], loss:0.9281
# epoch [28/100], loss:0.9174
# epoch [29/100], loss:0.9141
# epoch [30/100], loss:0.9113
# epoch [31/100], loss:0.9007
# epoch [32/100], loss:0.8888
# epoch [33/100], loss:0.8824
# epoch [34/100], loss:0.8774
# epoch [35/100], loss:0.8686
# epoch [36/100], loss:0.8578
# epoch [37/100], loss:0.8488
# epoch [38/100], loss:0.8424
# epoch [39/100], loss:0.8384
# epoch [40/100], loss:0.8371
# epoch [41/100], loss:0.8344
# epoch [42/100], loss:0.8314
# epoch [43/100], loss:0.8273
# epoch [44/100], loss:0.8194
# epoch [45/100], loss:0.8137
# epoch [46/100], loss:0.8115
# epoch [47/100], loss:0.8086
# epoch [48/100], loss:0.8059
# epoch [49/100], loss:0.8041
# epoch [50/100], loss:0.8020
# epoch [51/100], loss:0.7991
# epoch [52/100], loss:0.7963
# epoch [53/100], loss:0.7936
# epoch [54/100], loss:0.7904
# epoch [55/100], loss:0.7875
# epoch [56/100], loss:0.7856
# epoch [57/100], loss:0.7845
# epoch [58/100], loss:0.7838
# epoch [59/100], loss:0.7826
# epoch [60/100], loss:0.7803
# epoch [61/100], loss:0.7780
# epoch [62/100], loss:0.7759
# epoch [63/100], loss:0.7741
# epoch [64/100], loss:0.7730
# epoch [65/100], loss:0.7720
# epoch [66/100], loss:0.7706
# epoch [67/100], loss:0.7692
# epoch [68/100], loss:0.7679
# epoch [69/100], loss:0.7666
# epoch [70/100], loss:0.7653
# epoch [71/100], loss:0.7641
# epoch [72/100], loss:0.7631
# epoch [73/100], loss:0.7620
# epoch [74/100], loss:0.7610
# epoch [75/100], loss:0.7599
# epoch [76/100], loss:0.7587
# epoch [77/100], loss:0.7574
# epoch [78/100], loss:0.7564
# epoch [79/100], loss:0.7554
# epoch [80/100], loss:0.7545
# epoch [81/100], loss:0.7536
# epoch [82/100], loss:0.7526
# epoch [83/100], loss:0.7516
# epoch [84/100], loss:0.7507
# epoch [85/100], loss:0.7498
# epoch [86/100], loss:0.7490
# epoch [87/100], loss:0.7482
# epoch [88/100], loss:0.7474
# epoch [89/100], loss:0.7466
# epoch [90/100], loss:0.7458
# epoch [91/100], loss:0.7450
# epoch [92/100], loss:0.7442
# epoch [93/100], loss:0.7435
# epoch [94/100], loss:0.7428
# epoch [95/100], loss:0.7421
# epoch [96/100], loss:0.7413
# epoch [97/100], loss:0.7406
# epoch [98/100], loss:0.7399
# epoch [99/100], loss:0.7392
# epoch [100/100], loss:0.7385
# 4235
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 4, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(4, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:3.0943
# epoch [2/100], loss:2.7056
# epoch [3/100], loss:1.9975
# epoch [4/100], loss:2.0035
# epoch [5/100], loss:1.4683
# epoch [6/100], loss:1.4277
# epoch [7/100], loss:1.4103
# epoch [8/100], loss:1.2893
# epoch [9/100], loss:1.1720
# epoch [10/100], loss:1.1986
# epoch [11/100], loss:1.1495
# epoch [12/100], loss:1.0409
# epoch [13/100], loss:1.0358
# epoch [14/100], loss:1.0594
# epoch [15/100], loss:1.0479
# epoch [16/100], loss:1.0084
# epoch [17/100], loss:0.9787
# epoch [18/100], loss:0.9689
# epoch [19/100], loss:0.9410
# epoch [20/100], loss:0.9004
# epoch [21/100], loss:0.8838
# epoch [22/100], loss:0.8846
# epoch [23/100], loss:0.8814
# epoch [24/100], loss:0.8716
# epoch [25/100], loss:0.8665
# epoch [26/100], loss:0.8653
# epoch [27/100], loss:0.8542
# epoch [28/100], loss:0.8374
# epoch [29/100], loss:0.8276
# epoch [30/100], loss:0.8205
# epoch [31/100], loss:0.8088
# epoch [32/100], loss:0.7963
# epoch [33/100], loss:0.7901
# epoch [34/100], loss:0.7862
# epoch [35/100], loss:0.7779
# epoch [36/100], loss:0.7699
# epoch [37/100], loss:0.7649
# epoch [38/100], loss:0.7581
# epoch [39/100], loss:0.7479
# epoch [40/100], loss:0.7391
# epoch [41/100], loss:0.7332
# epoch [42/100], loss:0.7255
# epoch [43/100], loss:0.7172
# epoch [44/100], loss:0.7110
# epoch [45/100], loss:0.7037
# epoch [46/100], loss:0.6949
# epoch [47/100], loss:0.6877
# epoch [48/100], loss:0.6800
# epoch [49/100], loss:0.6709
# epoch [50/100], loss:0.6639
# epoch [51/100], loss:0.6582
# epoch [52/100], loss:0.6525
# epoch [53/100], loss:0.6477
# epoch [54/100], loss:0.6431
# epoch [55/100], loss:0.6385
# epoch [56/100], loss:0.6349
# epoch [57/100], loss:0.6311
# epoch [58/100], loss:0.6271
# epoch [59/100], loss:0.6234
# epoch [60/100], loss:0.6198
# epoch [61/100], loss:0.6167
# epoch [62/100], loss:0.6135
# epoch [63/100], loss:0.6102
# epoch [64/100], loss:0.6077
# epoch [65/100], loss:0.6050
# epoch [66/100], loss:0.6024
# epoch [67/100], loss:0.6001
# epoch [68/100], loss:0.5978
# epoch [69/100], loss:0.5959
# epoch [70/100], loss:0.5938
# epoch [71/100], loss:0.5916
# epoch [72/100], loss:0.5896
# epoch [73/100], loss:0.5875
# epoch [74/100], loss:0.5854
# epoch [75/100], loss:0.5834
# epoch [76/100], loss:0.5816
# epoch [77/100], loss:0.5798
# epoch [78/100], loss:0.5780
# epoch [79/100], loss:0.5764
# epoch [80/100], loss:0.5748
# epoch [81/100], loss:0.5733
# epoch [82/100], loss:0.5719
# epoch [83/100], loss:0.5705
# epoch [84/100], loss:0.5692
# epoch [85/100], loss:0.5679
# epoch [86/100], loss:0.5667
# epoch [87/100], loss:0.5656
# epoch [88/100], loss:0.5645
# epoch [89/100], loss:0.5634
# epoch [90/100], loss:0.5624
# epoch [91/100], loss:0.5614
# epoch [92/100], loss:0.5604
# epoch [93/100], loss:0.5595
# epoch [94/100], loss:0.5586
# epoch [95/100], loss:0.5578
# epoch [96/100], loss:0.5569
# epoch [97/100], loss:0.5561
# epoch [98/100], loss:0.5554
# epoch [99/100], loss:0.5546
# epoch [100/100], loss:0.5538
# 4669
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 6, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(6, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.7305
# epoch [2/100], loss:2.3831
# epoch [3/100], loss:1.9459
# epoch [4/100], loss:1.5985
# epoch [5/100], loss:1.4982
# epoch [6/100], loss:1.1895
# epoch [7/100], loss:1.1943
# epoch [8/100], loss:1.1265
# epoch [9/100], loss:1.0526
# epoch [10/100], loss:1.0580
# epoch [11/100], loss:0.9829
# epoch [12/100], loss:0.9480
# epoch [13/100], loss:0.9694
# epoch [14/100], loss:0.9635
# epoch [15/100], loss:0.9229
# epoch [16/100], loss:0.8912
# epoch [17/100], loss:0.8946
# epoch [18/100], loss:0.8896
# epoch [19/100], loss:0.8586
# epoch [20/100], loss:0.8370
# epoch [21/100], loss:0.8269
# epoch [22/100], loss:0.8160
# epoch [23/100], loss:0.7995
# epoch [24/100], loss:0.7844
# epoch [25/100], loss:0.7759
# epoch [26/100], loss:0.7624
# epoch [27/100], loss:0.7414
# epoch [28/100], loss:0.7275
# epoch [29/100], loss:0.7215
# epoch [30/100], loss:0.7135
# epoch [31/100], loss:0.7021
# epoch [32/100], loss:0.6901
# epoch [33/100], loss:0.6795
# epoch [34/100], loss:0.6729
# epoch [35/100], loss:0.6675
# epoch [36/100], loss:0.6604
# epoch [37/100], loss:0.6527
# epoch [38/100], loss:0.6439
# epoch [39/100], loss:0.6334
# epoch [40/100], loss:0.6233
# epoch [41/100], loss:0.6140
# epoch [42/100], loss:0.6048
# epoch [43/100], loss:0.5953
# epoch [44/100], loss:0.5867
# epoch [45/100], loss:0.5801
# epoch [46/100], loss:0.5730
# epoch [47/100], loss:0.5657
# epoch [48/100], loss:0.5599
# epoch [49/100], loss:0.5542
# epoch [50/100], loss:0.5489
# epoch [51/100], loss:0.5449
# epoch [52/100], loss:0.5402
# epoch [53/100], loss:0.5352
# epoch [54/100], loss:0.5319
# epoch [55/100], loss:0.5285
# epoch [56/100], loss:0.5245
# epoch [57/100], loss:0.5208
# epoch [58/100], loss:0.5168
# epoch [59/100], loss:0.5127
# epoch [60/100], loss:0.5093
# epoch [61/100], loss:0.5061
# epoch [62/100], loss:0.5034
# epoch [63/100], loss:0.5012
# epoch [64/100], loss:0.4988
# epoch [65/100], loss:0.4961
# epoch [66/100], loss:0.4937
# epoch [67/100], loss:0.4913
# epoch [68/100], loss:0.4890
# epoch [69/100], loss:0.4868
# epoch [70/100], loss:0.4846
# epoch [71/100], loss:0.4825
# epoch [72/100], loss:0.4804
# epoch [73/100], loss:0.4784
# epoch [74/100], loss:0.4767
# epoch [75/100], loss:0.4750
# epoch [76/100], loss:0.4733
# epoch [77/100], loss:0.4719
# epoch [78/100], loss:0.4705
# epoch [79/100], loss:0.4691
# epoch [80/100], loss:0.4677
# epoch [81/100], loss:0.4664
# epoch [82/100], loss:0.4651
# epoch [83/100], loss:0.4639
# epoch [84/100], loss:0.4628
# epoch [85/100], loss:0.4617
# epoch [86/100], loss:0.4606
# epoch [87/100], loss:0.4596
# epoch [88/100], loss:0.4587
# epoch [89/100], loss:0.4577
# epoch [90/100], loss:0.4567
# epoch [91/100], loss:0.4558
# epoch [92/100], loss:0.4549
# epoch [93/100], loss:0.4540
# epoch [94/100], loss:0.4531
# epoch [95/100], loss:0.4522
# epoch [96/100], loss:0.4513
# epoch [97/100], loss:0.4505
# epoch [98/100], loss:0.4496
# epoch [99/100], loss:0.4488
# epoch [100/100], loss:0.4479
# 5103
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 8, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(8, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.2604
# epoch [2/100], loss:1.8409
# epoch [3/100], loss:1.7348
# epoch [4/100], loss:1.4638
# epoch [5/100], loss:1.4288
# epoch [6/100], loss:1.3489
# epoch [7/100], loss:1.2408
# epoch [8/100], loss:1.2005
# epoch [9/100], loss:1.1494
# epoch [10/100], loss:1.0826
# epoch [11/100], loss:1.0580
# epoch [12/100], loss:0.9902
# epoch [13/100], loss:0.9246
# epoch [14/100], loss:0.9132
# epoch [15/100], loss:0.9059
# epoch [16/100], loss:0.8753
# epoch [17/100], loss:0.8588
# epoch [18/100], loss:0.8489
# epoch [19/100], loss:0.8198
# epoch [20/100], loss:0.7791
# epoch [21/100], loss:0.7553
# epoch [22/100], loss:0.7435
# epoch [23/100], loss:0.7260
# epoch [24/100], loss:0.7143
# epoch [25/100], loss:0.7110
# epoch [26/100], loss:0.7028
# epoch [27/100], loss:0.6872
# epoch [28/100], loss:0.6758
# epoch [29/100], loss:0.6642
# epoch [30/100], loss:0.6488
# epoch [31/100], loss:0.6367
# epoch [32/100], loss:0.6260
# epoch [33/100], loss:0.6130
# epoch [34/100], loss:0.6029
# epoch [35/100], loss:0.5963
# epoch [36/100], loss:0.5862
# epoch [37/100], loss:0.5765
# epoch [38/100], loss:0.5697
# epoch [39/100], loss:0.5618
# epoch [40/100], loss:0.5529
# epoch [41/100], loss:0.5454
# epoch [42/100], loss:0.5395
# epoch [43/100], loss:0.5337
# epoch [44/100], loss:0.5277
# epoch [45/100], loss:0.5220
# epoch [46/100], loss:0.5165
# epoch [47/100], loss:0.5110
# epoch [48/100], loss:0.5059
# epoch [49/100], loss:0.5015
# epoch [50/100], loss:0.4973
# epoch [51/100], loss:0.4929
# epoch [52/100], loss:0.4886
# epoch [53/100], loss:0.4850
# epoch [54/100], loss:0.4810
# epoch [55/100], loss:0.4766
# epoch [56/100], loss:0.4730
# epoch [57/100], loss:0.4689
# epoch [58/100], loss:0.4647
# epoch [59/100], loss:0.4612
# epoch [60/100], loss:0.4575
# epoch [61/100], loss:0.4539
# epoch [62/100], loss:0.4509
# epoch [63/100], loss:0.4476
# epoch [64/100], loss:0.4445
# epoch [65/100], loss:0.4415
# epoch [66/100], loss:0.4383
# epoch [67/100], loss:0.4353
# epoch [68/100], loss:0.4324
# epoch [69/100], loss:0.4295
# epoch [70/100], loss:0.4266
# epoch [71/100], loss:0.4239
# epoch [72/100], loss:0.4213
# epoch [73/100], loss:0.4187
# epoch [74/100], loss:0.4162
# epoch [75/100], loss:0.4137
# epoch [76/100], loss:0.4113
# epoch [77/100], loss:0.4090
# epoch [78/100], loss:0.4068
# epoch [79/100], loss:0.4047
# epoch [80/100], loss:0.4028
# epoch [81/100], loss:0.4009
# epoch [82/100], loss:0.3990
# epoch [83/100], loss:0.3972
# epoch [84/100], loss:0.3955
# epoch [85/100], loss:0.3937
# epoch [86/100], loss:0.3920
# epoch [87/100], loss:0.3904
# epoch [88/100], loss:0.3888
# epoch [89/100], loss:0.3872
# epoch [90/100], loss:0.3857
# epoch [91/100], loss:0.3841
# epoch [92/100], loss:0.3827
# epoch [93/100], loss:0.3812
# epoch [94/100], loss:0.3798
# epoch [95/100], loss:0.3784
# epoch [96/100], loss:0.3770
# epoch [97/100], loss:0.3757
# epoch [98/100], loss:0.3744
# epoch [99/100], loss:0.3731
# epoch [100/100], loss:0.3719
# 5537
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 10, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(10, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.8796
# epoch [2/100], loss:2.2485
# epoch [3/100], loss:1.9299
# epoch [4/100], loss:1.5230
# epoch [5/100], loss:1.4504
# epoch [6/100], loss:1.2984
# epoch [7/100], loss:1.2332
# epoch [8/100], loss:1.1794
# epoch [9/100], loss:1.0779
# epoch [10/100], loss:1.0765
# epoch [11/100], loss:1.0595
# epoch [12/100], loss:1.0272
# epoch [13/100], loss:1.0066
# epoch [14/100], loss:0.9616
# epoch [15/100], loss:0.9179
# epoch [16/100], loss:0.9008
# epoch [17/100], loss:0.8815
# epoch [18/100], loss:0.8634
# epoch [19/100], loss:0.8430
# epoch [20/100], loss:0.8114
# epoch [21/100], loss:0.7945
# epoch [22/100], loss:0.7785
# epoch [23/100], loss:0.7648
# epoch [24/100], loss:0.7582
# epoch [25/100], loss:0.7414
# epoch [26/100], loss:0.7303
# epoch [27/100], loss:0.7189
# epoch [28/100], loss:0.7058
# epoch [29/100], loss:0.6975
# epoch [30/100], loss:0.6821
# epoch [31/100], loss:0.6715
# epoch [32/100], loss:0.6560
# epoch [33/100], loss:0.6425
# epoch [34/100], loss:0.6293
# epoch [35/100], loss:0.6167
# epoch [36/100], loss:0.6091
# epoch [37/100], loss:0.5998
# epoch [38/100], loss:0.5930
# epoch [39/100], loss:0.5845
# epoch [40/100], loss:0.5767
# epoch [41/100], loss:0.5680
# epoch [42/100], loss:0.5598
# epoch [43/100], loss:0.5530
# epoch [44/100], loss:0.5460
# epoch [45/100], loss:0.5391
# epoch [46/100], loss:0.5324
# epoch [47/100], loss:0.5259
# epoch [48/100], loss:0.5194
# epoch [49/100], loss:0.5135
# epoch [50/100], loss:0.5074
# epoch [51/100], loss:0.5018
# epoch [52/100], loss:0.4961
# epoch [53/100], loss:0.4911
# epoch [54/100], loss:0.4858
# epoch [55/100], loss:0.4811
# epoch [56/100], loss:0.4763
# epoch [57/100], loss:0.4716
# epoch [58/100], loss:0.4673
# epoch [59/100], loss:0.4629
# epoch [60/100], loss:0.4586
# epoch [61/100], loss:0.4541
# epoch [62/100], loss:0.4498
# epoch [63/100], loss:0.4458
# epoch [64/100], loss:0.4419
# epoch [65/100], loss:0.4379
# epoch [66/100], loss:0.4338
# epoch [67/100], loss:0.4300
# epoch [68/100], loss:0.4262
# epoch [69/100], loss:0.4224
# epoch [70/100], loss:0.4186
# epoch [71/100], loss:0.4152
# epoch [72/100], loss:0.4117
# epoch [73/100], loss:0.4083
# epoch [74/100], loss:0.4049
# epoch [75/100], loss:0.4017
# epoch [76/100], loss:0.3985
# epoch [77/100], loss:0.3954
# epoch [78/100], loss:0.3926
# epoch [79/100], loss:0.3897
# epoch [80/100], loss:0.3869
# epoch [81/100], loss:0.3842
# epoch [82/100], loss:0.3815
# epoch [83/100], loss:0.3789
# epoch [84/100], loss:0.3764
# epoch [85/100], loss:0.3738
# epoch [86/100], loss:0.3714
# epoch [87/100], loss:0.3690
# epoch [88/100], loss:0.3666
# epoch [89/100], loss:0.3643
# epoch [90/100], loss:0.3621
# epoch [91/100], loss:0.3598
# epoch [92/100], loss:0.3577
# epoch [93/100], loss:0.3556
# epoch [94/100], loss:0.3536
# epoch [95/100], loss:0.3516
# epoch [96/100], loss:0.3497
# epoch [97/100], loss:0.3478
# epoch [98/100], loss:0.3459
# epoch [99/100], loss:0.3441
# epoch [100/100], loss:0.3424
# 5971
# Autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): Conv2d(16, 12, kernel_size=(3, 3), stride=(1, 1))
#     (2): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(12, 12, kernel_size=(3, 3), stride=(1, 1))
#     (1): ConvTranspose2d(12, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1))
#   )
# )
# epoch [1/100], loss:2.2149
# epoch [2/100], loss:1.6587
# epoch [3/100], loss:2.3113
# epoch [4/100], loss:1.3651
# epoch [5/100], loss:1.5544
# epoch [6/100], loss:1.6568
# epoch [7/100], loss:1.6609
# epoch [8/100], loss:1.6091
# epoch [9/100], loss:1.5162
# epoch [10/100], loss:1.3880
# epoch [11/100], loss:1.2493
# epoch [12/100], loss:1.1776
# epoch [13/100], loss:1.1767
# epoch [14/100], loss:1.0795
# epoch [15/100], loss:0.9872
# epoch [16/100], loss:0.9726
# epoch [17/100], loss:0.9825
# epoch [18/100], loss:0.9761
# epoch [19/100], loss:0.9485
# epoch [20/100], loss:0.9106
# epoch [21/100], loss:0.8764
# epoch [22/100], loss:0.8573
# epoch [23/100], loss:0.8547
# epoch [24/100], loss:0.8519
# epoch [25/100], loss:0.8306
# epoch [26/100], loss:0.7982
# epoch [27/100], loss:0.7734
# epoch [28/100], loss:0.7622
# epoch [29/100], loss:0.7588
# epoch [30/100], loss:0.7558
# epoch [31/100], loss:0.7490
# epoch [32/100], loss:0.7376
# epoch [33/100], loss:0.7230
# epoch [34/100], loss:0.7079
# epoch [35/100], loss:0.6952
# epoch [36/100], loss:0.6866
# epoch [37/100], loss:0.6806
# epoch [38/100], loss:0.6727
# epoch [39/100], loss:0.6610
# epoch [40/100], loss:0.6485
# epoch [41/100], loss:0.6384
# epoch [42/100], loss:0.6311
# epoch [43/100], loss:0.6251
# epoch [44/100], loss:0.6192
# epoch [45/100], loss:0.6128
# epoch [46/100], loss:0.6055
# epoch [47/100], loss:0.5972
# epoch [48/100], loss:0.5886
# epoch [49/100], loss:0.5806
# epoch [50/100], loss:0.5735
# epoch [51/100], loss:0.5670
# epoch [52/100], loss:0.5609
# epoch [53/100], loss:0.5546
# epoch [54/100], loss:0.5481
# epoch [55/100], loss:0.5416
# epoch [56/100], loss:0.5355
# epoch [57/100], loss:0.5298
# epoch [58/100], loss:0.5245
# epoch [59/100], loss:0.5195
# epoch [60/100], loss:0.5147
# epoch [61/100], loss:0.5100
# epoch [62/100], loss:0.5052
# epoch [63/100], loss:0.5004
# epoch [64/100], loss:0.4955
# epoch [65/100], loss:0.4907
# epoch [66/100], loss:0.4859
# epoch [67/100], loss:0.4813
# epoch [68/100], loss:0.4769
# epoch [69/100], loss:0.4725
# epoch [70/100], loss:0.4682
# epoch [71/100], loss:0.4641
# epoch [72/100], loss:0.4603
# epoch [73/100], loss:0.4567
# epoch [74/100], loss:0.4530
# epoch [75/100], loss:0.4492
# epoch [76/100], loss:0.4454
# epoch [77/100], loss:0.4419
# epoch [78/100], loss:0.4384
# epoch [79/100], loss:0.4350
# epoch [80/100], loss:0.4316
# epoch [81/100], loss:0.4282
# epoch [82/100], loss:0.4248
# epoch [83/100], loss:0.4215
# epoch [84/100], loss:0.4183
# epoch [85/100], loss:0.4151
# epoch [86/100], loss:0.4119
# epoch [87/100], loss:0.4086
# epoch [88/100], loss:0.4055
# epoch [89/100], loss:0.4024
# epoch [90/100], loss:0.3994
# epoch [91/100], loss:0.3963
# epoch [92/100], loss:0.3933
# epoch [93/100], loss:0.3904
# epoch [94/100], loss:0.3874
# epoch [95/100], loss:0.3845
# epoch [96/100], loss:0.3816
# epoch [97/100], loss:0.3787
# epoch [98/100], loss:0.3758
# epoch [99/100], loss:0.3730
# epoch [100/100], loss:0.3702
# 6405

# %%
for i in range(len(k2_tot)):
    plt.scatter(n_c_2[i],loss_tot_2[i],label="k2={}".format(i+1))
plt.xlabel("N_c")
plt.ylabel("Final Loss")
plt.legend()

# %%
loss_tot_2=np.reshape(loss_tot,(len(k2_tot),len(latent_space)))
for i in range(len(k2_tot)):
    plt.scatter(latent_space,loss_tot_2[i],label="k2={}".format(i+1))
plt.xlabel("latent space dimension")
plt.ylabel("Final Loss")
plt.legend()

# %%
print(loss_tot)
print(np.shape(loss_tot))
# Out:
# [0.743791937828064, 0.6061093211174011, 0.553595244884491, 0.496293842792511, 0.49442926049232483, 0.41922450065612793, 0.7481423020362854, 0.5762675404548645, 0.47340208292007446, 0.4285660684108734, 0.38566291332244873, 0.3936278223991394, 0.738466203212738, 0.5538272857666016, 0.447945237159729, 0.37185654044151306, 0.34239140152931213, 0.37015292048454285]
# (18,)

# %%
n_c_2=np.reshape(n_c_tot,(len(k2_tot),len(latent_space)))
for i in range(len(k2_tot)):
    plt.scatter(n_c_2[i],latent_space,label="k2={}".format(i+1))
plt.xlabel("N_c")
plt.ylabel("latent space dimension")
plt.legend()
